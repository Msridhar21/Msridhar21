# %% [markdown]
# # An exploratory analysis of crimes against women in india from 2001 to 2014 in different states

# %% [markdown]
# ### This project on crime on women in india from 2001 to 2014 to create awareness among the people in society about the situation of women

# %% [markdown]
# ## 1.data preparation and cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()
df=pd.read_csv('crimes_against_women_2001-2014.csv')
#df.describe()
df
# Out:
#        Unnamed: 0        STATE/UT           DISTRICT  Year  Rape  \
# 0               0  ANDHRA PRADESH           ADILABAD  2001    50
# 1               1  ANDHRA PRADESH          ANANTAPUR  2001    23
# 2               2  ANDHRA PRADESH           CHITTOOR  2001    27
# 3               3  ANDHRA PRADESH           CUDDAPAH  2001    20
# 4               4  ANDHRA PRADESH      EAST GODAVARI  2001    23
# ...           ...             ...                ...   ...   ...
# 10672         832     Lakshadweep        Lakshadweep  2014     1
# 10673         833     Lakshadweep  Total District(s)  2014     1
# 10674         834      Puducherry           Karaikal  2014     3
# 10675         835      Puducherry         Puducherry  2014     7
# 10676         836      Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 0                            30            16
# 1                            30             7
# ...

# %%
df.shape
# Out:
# (10677, 11)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0                                             0
# STATE/UT                                               0
# DISTRICT                                               0
# Year                                                   0
# Rape                                                   0
# Kidnapping and Abduction                               0
# Dowry Deaths                                           0
# Assault on women with intent to outrage her modesty    0
# Insult to modesty of Women                             0
# Cruelty by Husband or his Relatives                    0
# Importation of Girls                                   0
# dtype: int64

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df
# Out:
#              STATE/UT           DISTRICT  Year  Rape  \
# 0      ANDHRA PRADESH           ADILABAD  2001    50
# 1      ANDHRA PRADESH          ANANTAPUR  2001    23
# 2      ANDHRA PRADESH           CHITTOOR  2001    27
# 3      ANDHRA PRADESH           CUDDAPAH  2001    20
# 4      ANDHRA PRADESH      EAST GODAVARI  2001    23
# ...               ...                ...   ...   ...
# 10672     Lakshadweep        Lakshadweep  2014     1
# 10673     Lakshadweep  Total District(s)  2014     1
# 10674      Puducherry           Karaikal  2014     3
# 10675      Puducherry         Puducherry  2014     7
# 10676      Puducherry  Total District(s)  2014    10
#
#        Kidnapping and Abduction  Dowry Deaths  \
# 0                            30            16
# 1                            30             7
# 2                            34            14
# 3                            20            17
# 4                            26            12
# ...

# %%
dist_count=len(df['DISTRICT'].unique())
dist_count
# Out:
# 1605

# %%
df.drop(['DISTRICT'],axis=1,inplace=True)
df
# Out:
#              STATE/UT  Year  Rape  Kidnapping and Abduction  Dowry Deaths  \
# 0      ANDHRA PRADESH  2001    50                        30            16
# 1      ANDHRA PRADESH  2001    23                        30             7
# 2      ANDHRA PRADESH  2001    27                        34            14
# 3      ANDHRA PRADESH  2001    20                        20            17
# 4      ANDHRA PRADESH  2001    23                        26            12
# ...               ...   ...   ...                       ...           ...
# 10672     Lakshadweep  2014     1                         0             0
# 10673     Lakshadweep  2014     1                         0             0
# 10674      Puducherry  2014     3                         1             0
# 10675      Puducherry  2014     7                         6             1
# 10676      Puducherry  2014    10                         7             1
#
#        Assault on women with intent to outrage her modesty  \
# ...

# %%
df=df.rename(columns={
    'Kidnapping and Abduction':'Kidnapping_and_Abduction',
    'Dowry Deaths':'Dowry_Deaths',
    'Assault on women with intent to outrage her modesty':'Assault_on_women_with_intent_to_outrage_her_modesty',
    'Insult to modesty of Women':'Insult_to_modesty_of_Women',
    'Cruelty by Husband or his Relatives':'Cruelty_by_Husband_or_his_Relatives',
    'Importation of Girls':'Importation_of_Girls'
                     }
            )
df
# Out:
#              STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 0      ANDHRA PRADESH  2001    50                        30            16
# 1      ANDHRA PRADESH  2001    23                        30             7
# 2      ANDHRA PRADESH  2001    27                        34            14
# 3      ANDHRA PRADESH  2001    20                        20            17
# 4      ANDHRA PRADESH  2001    23                        26            12
# ...               ...   ...   ...                       ...           ...
# 10672     Lakshadweep  2014     1                         0             0
# 10673     Lakshadweep  2014     1                         0             0
# 10674      Puducherry  2014     3                         1             0
# 10675      Puducherry  2014     7                         6             1
# 10676      Puducherry  2014    10                         7             1
#
#        Assault_on_women_with_intent_to_outrage_her_modesty  \
# ...

# %%
print(df['STATE/UT'].unique())
print(len(df['STATE/UT'].unique()))
# Out:
# ['ANDHRA PRADESH' 'ARUNACHAL PRADESH' 'ASSAM' 'BIHAR' 'CHHATTISGARH' 'GOA'
#  'GUJARAT' 'HARYANA' 'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'KARNATAKA' 'KERALA' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR' 'MEGHALAYA'
#  'MIZORAM' 'NAGALAND' 'ODISHA' 'PUNJAB' 'RAJASTHAN' 'SIKKIM' 'TAMIL NADU'
#  'TRIPURA' 'UTTAR PRADESH' 'UTTARAKHAND' 'WEST BENGAL' 'A & N ISLANDS'
#  'CHANDIGARH' 'D & N HAVELI' 'DAMAN & DIU' 'DELHI' 'LAKSHADWEEP'
#  'PUDUCHERRY' 'Andhra Pradesh' 'Arunachal Pradesh' 'Assam' 'Bihar'
#  'Chhattisgarh' 'Goa' 'Gujarat' 'Haryana' 'Himachal Pradesh'
#  'Jammu & Kashmir' 'Jharkhand' 'Karnataka' 'Kerala' 'Madhya Pradesh'
#  'Maharashtra' 'Manipur' 'Meghalaya' 'Mizoram' 'Nagaland' 'Odisha'
#  'Punjab' 'Rajasthan' 'Sikkim' 'Tamil Nadu' 'Tripura' 'Uttar Pradesh'
#  'Uttarakhand' 'West Bengal' 'A&N Islands' 'Chandigarh' 'D&N Haveli'
#  'Daman & Diu' 'Delhi UT' 'Lakshadweep' 'Puducherry' 'Telangana'
#  'A & N Islands']
# 72

# %%
def cap_state(word):
    word=word['STATE/UT'].strip()
    word=word.upper()
    return word
df['STATE/UT']=df.apply(cap_state,axis=1)
df['STATE/UT']=df['STATE/UT'].replace(
    {
        'A&N ISLANDS':'A & N ISLANDS',
        'D&N HAVELI':'D & N HAVELI',
        'DELHI UT':'DELHI'
    }
                      )
    
print(df['STATE/UT'].unique())
print(len(df['STATE/UT'].unique()))
df
# Out:
# ['ANDHRA PRADESH' 'ARUNACHAL PRADESH' 'ASSAM' 'BIHAR' 'CHHATTISGARH' 'GOA'
#  'GUJARAT' 'HARYANA' 'HIMACHAL PRADESH' 'JAMMU & KASHMIR' 'JHARKHAND'
#  'KARNATAKA' 'KERALA' 'MADHYA PRADESH' 'MAHARASHTRA' 'MANIPUR' 'MEGHALAYA'
#  'MIZORAM' 'NAGALAND' 'ODISHA' 'PUNJAB' 'RAJASTHAN' 'SIKKIM' 'TAMIL NADU'
#  'TRIPURA' 'UTTAR PRADESH' 'UTTARAKHAND' 'WEST BENGAL' 'A & N ISLANDS'
#  'CHANDIGARH' 'D & N HAVELI' 'DAMAN & DIU' 'DELHI' 'LAKSHADWEEP'
#  'PUDUCHERRY' 'TELANGANA']
# 36
#              STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 0      ANDHRA PRADESH  2001    50                        30            16
# 1      ANDHRA PRADESH  2001    23                        30             7
# 2      ANDHRA PRADESH  2001    27                        34            14
# 3      ANDHRA PRADESH  2001    20                        20            17
# 4      ANDHRA PRADESH  2001    23                        26            12
# ...

# %% [markdown]
# ## 2.analysis and visualization of the data

# %%
norape=df.Rape.sum()
nokidnapped=df.Kidnapping_and_Abduction.sum()
nodowry=df.Dowry_Deaths.sum()
noassault=df.Assault_on_women_with_intent_to_outrage_her_modesty.sum()
noinsulted=df.Insult_to_modesty_of_Women.sum()
nocruelty=df.Cruelty_by_Husband_or_his_Relatives.sum()
noimported=df.Importation_of_Girls.sum()
total_no=0
total_no=norape+nokidnapped+nodowry+noassault+nocruelty+noinsulted+noimported
total_no
# Out:
# 5321610

# %% [markdown]
# ### It is clear that nearly 5 million women were suffered from various crimes against them from 2001 to 2014

# %% [markdown]
# ### now lets analyse with some statistics

# %%
fig, axes = plt.subplots(2, 3, figsize=(25, 12))

axes[0,0].bar(df.Year,df.Rape,color='r')
axes[0,0].set_title('Cases of Rape in India from 2001 to 2014')

axes[0,1].bar(df.Year,df.Kidnapping_and_Abduction,color='black')
axes[0,1].set_title('Cases on Kidnapping and abduction of women in India from 2001 to 2014')

axes[0,2].bar(df.Year,df.Dowry_Deaths,color='blue')
axes[0,2].set_title('Cases on Dowry deaths of women in India from 2001 to 2014')

axes[1,0].bar(df.Year,df.Insult_to_modesty_of_Women,color='orange')
axes[1,0].set_title('Cases of Insult on women in India from 2001 to 2014')

axes[1,1].bar(df.Year,df.Cruelty_by_Husband_or_his_Relatives,color='gray')
axes[1,1].set_title('Cases on Domestic voilence in India from 2001 to 2014')

axes[1,2].bar(df.Year,df.Importation_of_Girls,color='pink')
axes[1,2].set_title('Cases on Importation of girls in India from 2001 to 2014')
# Out:
# Text(0.5, 1.0, 'Cases on Importation of girls in India from 2001 to 2014')

# %% [markdown]
# ### from the graphs 2 things are  clear
# ### 1.Cases are increasing every year except the importation cases
# ### 2.2014 is the year with maximum crimes committed against women

# %%
count=df.groupby('Year')[['STATE/UT']].count()
count
# Out:
#       STATE/UT
# Year
# 2001       716
# 2002       719
# 2003       728
# 2004       729
# 2005       733
# 2006       740
# 2007       743
# 2008       761
# 2009       767
# 2010       779
# 2011       791
# 2012       811
# 2013       823
# 2014       837

# %%
plt.figure(figsize=(10,5))
plt.title('Total cases reported from every state Year wise')
sns.heatmap(count)
# Out:
# <AxesSubplot:title={'center':'Total cases reported from every state Year wise'}, ylabel='Year'>

# %% [markdown]
# ### top 10 rape cases reported from 2001 to 2014

# %%
top_10_rape_cases=df.sort_values('Rape',ascending=False).head(10)
top_10_rape_cases
# Out:
#              STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 10244  MADHYA PRADESH  2014  5076                      5688           733
# 9426   MADHYA PRADESH  2013  4335                      2873           776
# 10445       RAJASTHAN  2014  3759                      4421           408
# 10595   UTTAR PRADESH  2014  3467                     10626          2469
# 10291     MAHARASHTRA  2014  3438                      2457           279
# 8611   MADHYA PRADESH  2012  3425                      1127           743
# 7810   MADHYA PRADESH  2011  3406                      1088           811
# 9628        RAJASTHAN  2013  3285                      4047           453
# 7025   MADHYA PRADESH  2010  3135                      1030           892
# 9472      MAHARASHTRA  2013  3063                      1874           320
#
#        Assault_on_women_with_intent_to_outrage_her_modesty  \
# 10244                                               9609
# ...

# %% [markdown]
# ### top 10 Dowry cases reported in India

# %%
top_10_dowry_cases=df.sort_values('Dowry_Deaths',ascending=False).head(10)
top_10_dowry_cases
# Out:
#             STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 10595  UTTAR PRADESH  2014  3467                     10626          2469
# 9760   UTTAR PRADESH  2013  3050                      9737          2335
# 8132   UTTAR PRADESH  2011  2042                      7525          2322
# 8938   UTTAR PRADESH  2012  1963                      7910          2244
# 5796   UTTAR PRADESH  2008  1871                      4439          2237
# 6563   UTTAR PRADESH  2009  1759                      5078          2232
# 7342   UTTAR PRADESH  2010  1563                      5468          2217
# 650    UTTAR PRADESH  2001  1958                      2879          2211
# 5040   UTTAR PRADESH  2007  1648                      3363          2076
# 1366   UTTAR PRADESH  2002  1415                      2298          1893
#
#        Assault_on_women_with_intent_to_outrage_her_modesty  \
# 10595                                               8605
# ...

# %% [markdown]
# ### Top 10 domestic voilence cases in India

# %%
top_10_domestic_violance_cases = df.sort_values('Cruelty_by_Husband_or_his_Relatives', ascending = False).head(10)
top_10_domestic_violance_cases
# Out:
#              STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 10640     WEST BENGAL  2014  1466                      4976           501
# 8982      WEST BENGAL  2012  2046                      4168           593
# 8172      WEST BENGAL  2011  2363                      3711           510
# 9804      WEST BENGAL  2013  1685                      3830           481
# 7381      WEST BENGAL  2010  2311                      2764           507
# 6602      WEST BENGAL  2009  2336                      2187           506
# 10445       RAJASTHAN  2014  3759                      4421           408
# 9628        RAJASTHAN  2013  3285                      4047           453
# 9050   ANDHRA PRADESH  2013  1635                      1595           492
# 5835      WEST BENGAL  2008  2263                      1907           451
#
#        Assault_on_women_with_intent_to_outrage_her_modesty  \
# 10640                                               5670
# ...

# %%
top_10_Kidnapping_cases = df.sort_values('Kidnapping_and_Abduction', ascending = False).head(10)
top_10_Kidnapping_cases
# Out:
#              STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 10595   UTTAR PRADESH  2014  3467                     10626          2469
# 9760    UTTAR PRADESH  2013  3050                      9737          2335
# 8938    UTTAR PRADESH  2012  1963                      7910          2244
# 8132    UTTAR PRADESH  2011  2042                      7525          2322
# 10244  MADHYA PRADESH  2014  5076                      5688           733
# 7342    UTTAR PRADESH  2010  1563                      5468          2217
# 6563    UTTAR PRADESH  2009  1759                      5078          2232
# 10640     WEST BENGAL  2014  1466                      4976           501
# 9955            BIHAR  2014  1127                      4735          1373
# 5796    UTTAR PRADESH  2008  1871                      4439          2237
#
#        Assault_on_women_with_intent_to_outrage_her_modesty  \
# 10595                                               8605
# ...

# %%
top_10_insulting_cases = df.sort_values('Insult_to_modesty_of_Women', ascending = False).head(10)
top_10_insulting_cases
# Out:
#             STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 2095   UTTAR PRADESH  2003   911                      1499          1322
# 9050  ANDHRA PRADESH  2013  1635                      1595           492
# 6669  ANDHRA PRADESH  2010  1362                      1531           588
# 8239  ANDHRA PRADESH  2012  1341                      1403           504
# 7448  ANDHRA PRADESH  2011  1442                      1612           599
# 5137  ANDHRA PRADESH  2008  1257                      1396           556
# 5898  ANDHRA PRADESH  2009  1188                      1526           546
# 5796   UTTAR PRADESH  2008  1871                      4439          2237
# 4394  ANDHRA PRADESH  2007  1070                      1564           613
# 5040   UTTAR PRADESH  2007  1648                      3363          2076
#
#       Assault_on_women_with_intent_to_outrage_her_modesty  \
# 2095                                               1098
# ...

# %% [markdown]
# ### top states with highest crime rate in India from 2001 to 2014

# %%
df_count=df.groupby('STATE/UT')[['Rape','Kidnapping_and_Abduction','Dowry_Deaths','Cruelty_by_Husband_or_his_Relatives','Importation_of_Girls']].sum()
df_count
# Out:
#                     Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# STATE/UT
# A & N ISLANDS        336                       212            20
# ANDHRA PRADESH     32150                     34504         13844
# ARUNACHAL PRADESH   1316                      1470             6
# ASSAM              40190                     62074          3268
# BIHAR              30758                     57086         32206
# CHANDIGARH           770                      1682            90
# CHHATTISGARH       29308                     11808          2758
# D & N HAVELI         132                       224             2
# DAMAN & DIU           60                        44             6
# DELHI              20312                     46586          3758
# GOA                 1062                       640            38
# GUJARAT            11644                     34670          1108
# HARYANA            17110                     20016          7372
# ...

# %% [markdown]
# ### states with top 5 Rape cases in India from 2001 to 2014

# %%
df_count.sort_values(by='Rape',ascending=False).head(5)
# Out:
#                  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# STATE/UT
# MADHYA PRADESH  90996                     35608         21090
# UTTAR PRADESH   51150                    135906         57256
# MAHARASHTRA     48974                     30368          9696
# WEST BENGAL     47876                     61158         12308
# RAJASTHAN       45684                     66278         11854
#
#                 Cruelty_by_Husband_or_his_Relatives  Importation_of_Girls
# STATE/UT
# MADHYA PRADESH                               102816                   134
# UTTAR PRADESH                                193738                     6
# MAHARASHTRA                                  193202                     6
# WEST BENGAL                                  344124                   254
# RAJASTHAN                                    262200                    14

# %% [markdown]
# ### Madhya pradesh top the list of rape cases from 2001 to 2014 in India,it is followed by Uttar pradesh,Maharashtra,West Bengal,and Rajasthan

# %% [markdown]
# ### states with top 5 Dowry death cases in India from 2001 to 2014

# %%
df_count.sort_values(by='Dowry_Deaths',ascending=False).head(5)
# Out:
#                  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# STATE/UT
# UTTAR PRADESH   51150                    135906         57256
# BIHAR           30758                     57086         32206
# MADHYA PRADESH  90996                     35608         21090
# ANDHRA PRADESH  32150                     34504         13844
# WEST BENGAL     47876                     61158         12308
#
#                 Cruelty_by_Husband_or_his_Relatives  Importation_of_Girls
# STATE/UT
# UTTAR PRADESH                                193738                     6
# BIHAR                                         69770                   904
# MADHYA PRADESH                               102816                   134
# ANDHRA PRADESH                               280906                    34
# WEST BENGAL                                  344124                   254

# %% [markdown]
# ### Uttar pradesh top the list of Dowry Death cases from 2001 to 2014 in India,it is followed by Bihar,Madhya pradesh,Andhra pradesh and West Bengal.

# %% [markdown]
# ### states with top 5 kidnapping cases in India from 2001 to 2014

# %%
df_count.sort_values(by='Kidnapping_and_Abduction',ascending=False).head(5)
# Out:
#                 Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# STATE/UT
# UTTAR PRADESH  51150                    135906         57256
# RAJASTHAN      45684                     66278         11854
# ASSAM          40190                     62074          3268
# WEST BENGAL    47876                     61158         12308
# BIHAR          30758                     57086         32206
#
#                Cruelty_by_Husband_or_his_Relatives  Importation_of_Girls
# STATE/UT
# UTTAR PRADESH                               193738                     6
# RAJASTHAN                                   262200                    14
# ASSAM                                       115300                    22
# WEST BENGAL                                 344124                   254
# BIHAR                                        69770                   904

# %% [markdown]
# ### Uttar pradesh top the list of Kidnapping cases from 2001 to 2014 in India,it is followed by Rajasthan,Assam,West Bengal and Bihar.

# %% [markdown]
# ### states with top 5 domestic voilence cases in India from 2001 to 2014

# %%
df_count.sort_values(by='Cruelty_by_Husband_or_his_Relatives',ascending=False).head(5)
# Out:
#                  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# STATE/UT
# WEST BENGAL     47876                     61158         12308
# ANDHRA PRADESH  32150                     34504         13844
# RAJASTHAN       45684                     66278         11854
# UTTAR PRADESH   51150                    135906         57256
# MAHARASHTRA     48974                     30368          9696
#
#                 Cruelty_by_Husband_or_his_Relatives  Importation_of_Girls
# STATE/UT
# WEST BENGAL                                  344124                   254
# ANDHRA PRADESH                               280906                    34
# RAJASTHAN                                    262200                    14
# UTTAR PRADESH                                193738                     6
# MAHARASHTRA                                  193202                     6

# %% [markdown]
# ### West Bengal top the list of Kidnapping cases from 2001 to 2014 in India,it is followed by Andhra pradesh,Rajasthan,Uttar pradesh and Mahrashtra.

# %% [markdown]
# ### states with top 5 imported girls cases in India from 2001 to 2014

# %%
df_count.sort_values(by='Importation_of_Girls',ascending=False).head(5)
# Out:
#                  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# STATE/UT
# BIHAR           30758                     57086         32206
# JHARKHAND       22826                     14186          7896
# WEST BENGAL     47876                     61158         12308
# MADHYA PRADESH  90996                     35608         21090
# KARNATAKA       15056                     16262          7016
#
#                 Cruelty_by_Husband_or_his_Relatives  Importation_of_Girls
# STATE/UT
# BIHAR                                         69770                   904
# JHARKHAND                                     23910                   298
# WEST BENGAL                                  344124                   254
# MADHYA PRADESH                               102816                   134
# KARNATAKA                                     72706                    94

# %% [markdown]
# ### Bihar top the list of Kidnapping cases from 2001 to 2014 in India,it is followed by Jharkhand,West Bengal,Madhya pradesh and Karnataka.¶

# %% [markdown]
# ### top state with rape and Dowry Death cases from 2001 to 2014 in India

# %%
Rd=top_10_rape_cases.merge(top_10_dowry_cases)
Rd
# Out:
#         STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 0  UTTAR PRADESH  2014  3467                     10626          2469
#
#    Assault_on_women_with_intent_to_outrage_her_modesty  \
# 0                                               8605
#
#    Insult_to_modesty_of_Women  Cruelty_by_Husband_or_his_Relatives  \
# 0                          29                                10471
#
#    Importation_of_Girls
# 0                     0

# %% [markdown]
# ### Uttar pradesh stood top in both the Rape and Dowry Death cases

# %% [markdown]
# ### top state with Rape and imported girls cases from 2001 to 2014 in India

# %%
Ri=top_10_rape_cases.merge(top_10_dowry_cases)
Ri
# Out:
#         STATE/UT  Year  Rape  Kidnapping_and_Abduction  Dowry_Deaths  \
# 0  UTTAR PRADESH  2014  3467                     10626          2469
#
#    Assault_on_women_with_intent_to_outrage_her_modesty  \
# 0                                               8605
#
#    Insult_to_modesty_of_Women  Cruelty_by_Husband_or_his_Relatives  \
# 0                          29                                10471
#
#    Importation_of_Girls
# 0                     0

# %% [markdown]
# ### Uttar pradesh stood top in both the Rape and imported girl cases
